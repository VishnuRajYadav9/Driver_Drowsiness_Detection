# %%
from ultralytics import YOLO
import supervision as sv
model = YOLO("yolov8n.pt")
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:01<00:00, 4.86MB/s]

# %%
model.train(data = "D:\drowsiness detection 2\data\data.yaml",epochs = 100,batch=16,imgsz=650,save=True,workers=4,val = False,patience = 25)
# Out:
# Ultralytics YOLOv8.0.123  Python-3.11.3 torch-2.0.1+cpu CPU
# ...
